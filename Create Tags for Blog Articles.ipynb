# %% [markdown]
# # Install Spacy and the language for the blog
# By the first time you need to restart the runtime and run it twice

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already up-to-date: spacy in /usr/local/lib/python3.7/dist-packages (3.0.6)
# ...
# 2021-05-01 12:16:14.355913: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy

# %%
from collections import Counter
from string import punctuation

# %%
nlp = spacy.load("en_core_web_lg")

# %%
import en_core_web_lg
nlp = en_core_web_lg.load()

# %% [markdown]
# # Function for our Tags

# %%
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] # 1
    doc = nlp(text.lower()) # 2
    for token in doc:
        # 3
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        # 4
        if(token.pos_ in pos_tag):
            result.append(token.text)
                
    return result # 5

# %%
output = get_hotwords('''Infor Enterprise Asset Management (EAM) involves the management and maintenance of physical assets of a company. We have developed an app called Finder. Its main goal is to facilitate the maintenance process by creating work orders more rapidly from images.''')
print(output)
# Out:
# ['enterprise', 'asset', 'management', 'eam', 'management', 'maintenance', 'physical', 'assets', 'company', 'app', 'finder', 'main', 'goal', 'maintenance', 'process', 'work', 'orders', 'images']
