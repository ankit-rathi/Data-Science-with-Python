# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-rathi/Data-Science-with-Python/blob/master/Tradevesting/myStocks_Comprehensive_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import pytz
tz_NY = pytz.timezone('Asia/Kolkata')
datetime_NY = datetime.datetime.now(tz_NY)
print("Run date time (IST):", datetime_NY.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Run date time (IST): 2023-07-05 18:12:00

# %%
# install libraries
# !pip install yfinance
# !pip install pandas-ta
#!pip install talib-binary
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.21)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=59ecb7436b88d15b04174fc1539cadb72388016f9128b70df857256f44e23951
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')

df_ps_features = pd.read_csv('/content/drive/My Drive/data/stocks/myProspects-Upside-Analysis-ATH.csv')

df_pf_analysis = pd.read_csv('/content/drive/My Drive/data/stocks/myStocks-Portfolio-Analysis.csv')

df_ps_buysell = pd.read_csv('/content/drive/My Drive/data/stocks/myProspects-Buy-Sell-Signals.csv')

df_ps_accdis = pd.read_csv('/content/drive/My Drive/data/stocks/myProspects-Acc-Dis-Signals.csv')
# Out:
# Mounted at /content/drive

# %%
df_ps_features.columns
# Out:
# Index(['Stock', 'Close', 'Dev%_200', 'Slope%_200', 'Slope%_50', 'Max', 'Min',
#        'Discount%', 'Upside%ATH', 'Conviction', 'LatestQtr', 'StarStock',
#        'Criteria', 'Strategy'],
#       dtype='object')

# %%
cols_a = ['Stock','Dev%_200','Upside%ATH','Criteria','Strategy','StarStock']
cols_b = ['Stock','Current P/L%','Weightage%','Investment']
tmp_a = df_ps_features[cols_a]
tmp_b = df_pf_analysis[cols_b]
tmp_df = pd.merge(tmp_a, tmp_b, on='Stock', how='inner')
tmp_df.sort_values(by = 'Dev%_200', ascending=True)
# Out:
#             Stock  Dev%_200  Upside%ATH Criteria Strategy  StarStock  \
# 17       GLAND.NS    -28.30       306.0     2T3Y     2T3Y        0.0
# 34  RAJESHEXPO.NS    -20.77        79.0     V40N      ATH        1.0
# 1        AAVAS.NS    -13.90       108.0     2T3Y     2T3Y        1.0
# 31     PAGEIND.NS    -13.71        46.0      V40      ATH        1.0
# 14     FINEORG.NS     -9.43        49.0     V40N      ATH        1.0
# 11       CLEAN.NS     -7.30        92.0     2T3Y     2T3Y        1.0
# 7   BANDHANBNK.NS     -6.27       221.0     2T3Y     2T3Y        1.0
# 3    AMBUJACEM.NS     -6.20        36.0      TBD      ATH        0.0
# 38       SUNTV.NS     -4.43        60.0     V40N      ATH        1.0
# 22        INFY.NS     -4.17        37.0      V40      ATH        1.0
# 43  VALIANTORG.NS     -4.01       242.0     2T3Y     2T3Y        0.0
# 40   TEAMLEASE.NS     -3.74       119.0     V40N     2T3Y        1.0
# 23       IRCTC.NS     -3.73        84.0       SS      ATH        1.0
# 42  VAIBHAVGBL.NS     -3.28       213.0     2T3Y     2T3Y        0.0
# 26    JUBLFOOD.NS     -2.65        83.0       SS      ATH        1.0
# 28      LUXIND.NS     -2.07       203.0     V40N     2T3Y        0.0
# 12       DMART.NS      0.63        39.0       SS      ATH        1.0
# 44       WIPRO.NS      1.00        81.0     2T3Y     2T3Y        0.0
# 13    EMAMILTD.NS      1.25        39.0     V200      ATH        1.0
# 35      RELAXO.NS      1.73        59.0     V40N     2T3Y        0.0
# 32  PIDILITIND.NS      2.87        11.0      V40      ATH        1.0
# 9    BAYERCROP.NS      3.26        31.0     V40N      ATH        1.0
# 8    BATAINDIA.NS      3.36        31.0      V40      ATH        0.0
# 39         TCS.NS      3.43        16.0      V40      ATH        1.0
# 24      ITBEES.NS      4.20        29.0       SS      ATH        1.0
# 36    RELIANCE.NS      4.98         9.0      V40      ATH        1.0
# 29  METROPOLIS.NS      6.56       135.0      TBD      ATH        0.0
# 16    GILLETTE.NS      6.80        47.0      V40      ATH        0.0
# 5   BAJAJFINSV.NS      8.16        18.0      V40      ATH        1.0
# 30       NIACL.NS      8.55       162.0      TBD      ATH        0.0
# 25  JMFINANCIL.NS      9.04        59.0     2T3Y     2T3Y        0.0
# 10        CDSL.NS      9.37        38.0       SS      ATH        1.0
# 20  INDIGOPNTS.NS     10.29       118.0     V40N     2T3Y        1.0
# 37     ROSSARI.NS     10.64        86.0     2T3Y     2T3Y        1.0
# 4   ASIANPAINT.NS     11.40         5.0      V40      ATH        1.0
# 27        LTIM.NS     13.03        42.0     V200      ATH        1.0
# 19     ICICIGI.NS     14.80        22.0      V40      ATH        1.0
# 2   AMARAJABAT.NS     16.73        44.0     V200      ATH        1.0
# 15       GICRE.NS     18.73        96.0     2T3Y     2T3Y        0.0
# 21  INDUSINDBK.NS     19.82        40.0       SS      ATH        1.0
# 18     HDFCAMC.NS     19.83        53.0      V40      ATH        0.0
# 6   BAJFINANCE.NS     19.93         0.0      V40      ATH        1.0
# 33         PNB.NS     22.08        61.0       SS      ATH        1.0
# 0       5PAISA.NS     29.01        34.0     V40N      ATH        1.0
# 41  UJJIVANSFB.NS     45.18        39.0     V40N      ATH        1.0
#
#     Current P/L%  Weightage%  Investment
# 17        -13.20        2.25    67422.85
# 34        -15.29        1.00    29989.44
# 1          10.77        1.07    31983.80
# 31         -6.62        3.94   117975.09
# 14          3.07        1.73    51671.73
# 11         -1.29        1.07    32119.27
# 7         -11.43        2.54    76194.00
# 3           1.98        2.55    76323.60
# 38         -0.74        1.01    30379.00
# 22          6.67        2.53    75780.00
# 43         -0.03        2.61    78122.88
# 40          5.68        1.60    47878.53
# 23         -0.39        2.54    75966.00
# 42         -2.81        1.53    45717.12
# 26          4.66        2.58    77335.84
# 28          0.37        2.54    76179.72
# 12          4.04        2.57    77109.27
# 44          1.50        2.53    75673.65
# 13         -0.09        1.02    30426.48
# 35          1.60        2.52    75576.90
# 32          4.18        2.51    75121.80
# 9           9.48        1.54    46037.64
# 8           8.88        5.09   152362.00
# 39          2.75        1.73    51696.00
# 24          3.96        1.68    50367.25
# 36          4.76        2.55    76481.65
# 29          6.96        1.00    30051.56
# 16         14.61        3.14    93992.85
# 5          10.91        2.53    75656.36
# 30         -0.79        1.52    45657.30
# 25          7.20        1.56    46689.75
# 10         16.50        1.68    50325.45
# 20          1.46        5.83   174558.52
# 37         -0.16        1.02    30398.40
# 4           9.16        2.58    77283.50
# 27          4.92        1.67    49963.70
# 19         16.64        2.62    78508.20
# 2           9.78        1.50    45018.00
# 15          4.98        1.34    40235.58
# 21          7.54        1.56    46852.92
# 18         22.09        2.57    77066.06
# 6          18.73        5.29   158451.60
# 33         15.24        1.53    45765.00
# 0          18.58        2.64    79129.68
# 41         16.58        1.57    47074.50

# %%
# candidates for SIP
tmp_df[(tmp_df['Weightage%'] < 2) & (tmp_df['Weightage%'] < 2)]
# Out:
#             Stock  Dev%_200  Upside%ATH Criteria Strategy  StarStock  \
# 1        AAVAS.NS    -13.90       108.0     2T3Y     2T3Y        1.0
# 2   AMARAJABAT.NS     16.73        44.0     V200      ATH        1.0
# 9    BAYERCROP.NS      3.26        31.0     V40N      ATH        1.0
# 10        CDSL.NS      9.37        38.0       SS      ATH        1.0
# 11       CLEAN.NS     -7.30        92.0     2T3Y     2T3Y        1.0
# 13    EMAMILTD.NS      1.25        39.0     V200      ATH        1.0
# 14     FINEORG.NS     -9.43        49.0     V40N      ATH        1.0
# 15       GICRE.NS     18.73        96.0     2T3Y     2T3Y        0.0
# 21  INDUSINDBK.NS     19.82        40.0       SS      ATH        1.0
# 24      ITBEES.NS      4.20        29.0       SS      ATH        1.0
# 25  JMFINANCIL.NS      9.04        59.0     2T3Y     2T3Y        0.0
# 27        LTIM.NS     13.03        42.0     V200      ATH        1.0
# 29  METROPOLIS.NS      6.56       135.0      TBD      ATH        0.0
# 30       NIACL.NS      8.55       162.0      TBD      ATH        0.0
# 33         PNB.NS     22.08        61.0       SS      ATH        1.0
# 34  RAJESHEXPO.NS    -20.77        79.0     V40N      ATH        1.0
# 37     ROSSARI.NS     10.64        86.0     2T3Y     2T3Y        1.0
# 38       SUNTV.NS     -4.43        60.0     V40N      ATH        1.0
# 39         TCS.NS      3.43        16.0      V40      ATH        1.0
# 40   TEAMLEASE.NS     -3.74       119.0     V40N     2T3Y        1.0
# 41  UJJIVANSFB.NS     45.18        39.0     V40N      ATH        1.0
# 42  VAIBHAVGBL.NS     -3.28       213.0     2T3Y     2T3Y        0.0
#
#     Current P/L%  Weightage%  Investment
# 1          10.77        1.07    31983.80
# 2           9.78        1.50    45018.00
# 9           9.48        1.54    46037.64
# 10         16.50        1.68    50325.45
# 11         -1.29        1.07    32119.27
# 13         -0.09        1.02    30426.48
# 14          3.07        1.73    51671.73
# 15          4.98        1.34    40235.58
# 21          7.54        1.56    46852.92
# 24          3.96        1.68    50367.25
# 25          7.20        1.56    46689.75
# 27          4.92        1.67    49963.70
# 29          6.96        1.00    30051.56
# 30         -0.79        1.52    45657.30
# 33         15.24        1.53    45765.00
# 34        -15.29        1.00    29989.44
# 37         -0.16        1.02    30398.40
# 38         -0.74        1.01    30379.00
# 39          2.75        1.73    51696.00
# 40          5.68        1.60    47878.53
# 41         16.58        1.57    47074.50
# 42         -2.81        1.53    45717.12
